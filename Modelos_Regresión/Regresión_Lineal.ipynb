# %% [markdown]
# # Regresión Lineal

# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# read data into a DataFrame
data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/scikit-learn-videos/master/data/Advertising.csv', index_col=0)
data.columns = ['TV','Radio','Newspaper','Sales']
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
import seaborn as sns
sns.pairplot(data,diag_kind='kde')

# %%
data.head(10)
# Out:
#        TV  Radio  Newspaper  Sales
# 1   230.1   37.8       69.2   22.1
# 2    44.5   39.3       45.1   10.4
# 3    17.2   45.9       69.3    9.3
# 4   151.5   41.3       58.5   18.5
# 5   180.8   10.8       58.4   12.9
# 6     8.7   48.9       75.0    7.2
# 7    57.5   32.8       23.5   11.8
# 8   120.2   19.6       11.6   13.2
# 9     8.6    2.1        1.0    4.8
# 10  199.8    2.6       21.2   10.6

# %% [markdown]
# Variables Descriptivas (Input)
#
# - **TV:** Advertising dollars spent on TV for a single product in a given market (in thousands of dollars)
# - **Radio:** Advertising dollars spent on Radio
# - **Newspaper:** Advertising dollars spent on Newspaper
#
# Variable Respuesta (Output)
#
# - **Sales:** sales of a single product in a given market (in thousands of widgets)

# %% [markdown]
# # Ajuste lineal

# %% [markdown]
# Simple Linear regression is an approach for predicting a **quantitative response** using a **single feature** (or "predictor" or "input variable"). It takes the following form:
#
# $y = \beta_0 + \beta_1x$
#
# What does each term represent?
# - $y$ is the response
# - $x$ is the feature
# - $\beta_0$ is the intercept
# - $\beta_1$ is the coefficient for x
#
# Together, $\beta_0$ and $\beta_1$ are called the **model coefficients**. To create your model, you must "learn" the values of these coefficients. And once we've learned these coefficients, we can use the model to predict Sales!

# %%
# create X and y
feature_cols = ['TV']
X = data[feature_cols]
y = data.Sales

# follow the usual sklearn pattern: import, instantiate, fit
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X, y)

# print intercept and coefficients
print(lm.intercept_)
print(lm.coef_)
# Out:
# 7.032593549127695
# [0.04753664]

# %% [markdown]
# Realizar predicción

# %%
# Nuevo Dato
X_new = pd.DataFrame({'TV': [60]})
X_new.head()
# predecir para un nuevo valor
lm.predict(X_new)
# Out:
# array([9.88479198])

# %%
print(lm.intercept_ + lm.coef_*60)
# Out:
# [9.88479198]

# %% [markdown]
# Plot ajuste

# %%
X_new = pd.DataFrame({'TV': [data.TV.min(), data.TV.max()]})
X_new.head()

# Realizar predicciones
preds = lm.predict(X_new)
preds

# Plot dato observado
data.plot(kind='scatter', x='TV', y='Sales')

# Plot ajuste
plt.plot(X_new, preds, c='red', linewidth=2)

# %%
# Pre Modeling
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
import seaborn as sns

data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/scikit-learn-videos/master/data/Advertising.csv', index_col=0)
data.columns = ['TV','Radio','Newspaper','Sales']
data.head()
X = data.drop(["Sales"],axis=1)
y = data.Sales
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state = 0,test_size=0.25)


regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
y_pred = regr.predict(X_train)

y_pred_test = regr.predict(X_test)

print("R squared: {}".format(r2_score(y_true=y_train,y_pred=y_pred)))
print("R squared: {}".format(r2_score(y_true=y_test,y_pred=y_pred_test)))
# Out:
# R squared: 0.9072183330817297
# R squared: 0.8576396745320893

# %%
import statsmodels.formula.api as smf
import statsmodels.api as sm
fit_lm = smf.ols(formula='Sales ~ TV + Radio + Newspaper', data=data).fit()
print(fit_lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):           1.58e-96
# Time:                        11:11:22   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# TV             0.0458      0.001     32.809      0.000       0.043       0.049
# Radio          0.1885      0.009     21.893      0.000       0.172       0.206
# Newspaper     -0.0010      0.006     -0.177      0.860      -0.013       0.011
# ==============================================================================
# Omnibus:                       60.414   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.241
# Skew:                          -1.327   Prob(JB):                     1.44e-33
# Kurtosis:                       6.332   Cond. No.                         454.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Ejercicios de validación del modelo
#
# 1. Media residuos igual a cero: Media residuos igual a 0
# 2. Homoscedasticidad: Residuos con misma varianza
# 3. Normalidad de los errores: distribución
# 4. No autocorrelación de los residuos: no tienen correlación por orden de magnitud
# 5. No Multicollinearidad

# %%
y_pred = fit_lm.predict(data[['TV','Radio','Newspaper']])
y = data['Sales']


## Valor de la media de los residuos

residuals = y-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 7.638334409421077e-16

# %%
p = sns.scatterplot(x=y_pred,y=residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot(x=[0,26],y=[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')

# %%
p = sns.distplot(residuals,kde=True)
p = plt.title('Normality of error terms/residuals')
# Out:
# <ipython-input-14-399e0398f458>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   p = sns.distplot(residuals,kde=True)

# %%
plt.figure(figsize=(10,5))
p = sns.lineplot(x=y_pred,y=residuals,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot(x=[0,26],y=[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')

# %%
# Gráfico de autocorrelación
sm.graphics.tsa.plot_acf(residuals, lags=20)
plt.show()

# %%
plt.figure(figsize=(8,8))
p=sns.heatmap(data.corr(), annot=True,cmap='RdYlGn',square=True)

# %% [markdown]
# # Ejercicio
# - Teniendo en cuenta que la variable Newspaper no es significativa, construye de nuevo el modelo

# %%
fit_lm = smf.ols(formula='Sales ~ TV + Radio', data=data).fit()
print(fit_lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):           4.83e-98
# Time:                        11:11:26   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# TV             0.0458      0.001     32.909      0.000       0.043       0.048
# Radio          0.1880      0.008     23.382      0.000       0.172       0.204
# ==============================================================================
# Omnibus:                       60.022   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.679
# Skew:                          -1.323   Prob(JB):                     5.19e-33
# Kurtosis:                       6.292   Cond. No.                         425.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Ejercicios de validación del modelo
#
# 1. Media residuos igual a cero: Media residuos igual a 0
# 2. Homoscedasticidad: Residuos con misma varianza
# 3. Normalidad de los errores: distribución
# 4. No autocorrelación de los residuos: no tienen correlación por orden de magnitud
# 5. No Multicollinearidad

# %%
y_pred = fit_lm.predict(data[['TV','Radio']])
y = data['Sales']

## Valor de la media de los residuos

residuals = y-y_pred
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 6.0662586065518554e-15

# %%
residuals
# Out:
# 1      1.544535
# 2     -1.945362
# 3     -3.037018
# 4      0.882884
# 5     -0.323908
#          ...
# 196    2.235488
# 197    1.547625
# 198    0.031952
# 199    1.707077
# 200   -1.757543
# Length: 200, dtype: float64

# %%
# Ralizamos las predicciones y sacamos el vector y^
p = sns.scatterplot(x=y_pred, y=residuals)
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot(x=[0,26],y=[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')

# %%
# Calculamos los residuos y sacamos su valor de la media de los residuos
p = sns.distplot(residuals,kde=True)
p = plt.title('Normality of error terms/residuals')
# Out:
# <ipython-input-22-19501738cee7>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   p = sns.distplot(residuals,kde=True)

# %%
# Homoscedasticidad de los residuos
plt.figure(figsize=(10,5))
p = sns.lineplot(x=y_pred,y=residuals,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,26)
p = sns.lineplot(x=[0,26],y=[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')

# %%
## Distribución de los residuos
## Normalidad de los errores: distribución
plt.figure(figsize=(8,8))  # on this line I just set the size of figure to 12 by 10.
p=sns.heatmap(data[['TV','Radio','Sales']].corr(), annot=True,cmap='RdYlGn',square=True)  # seaborn has very simple solution for heatmap

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# # Ejercicio 2

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JimenaAreta/thevalley-MDS/jimena/datasets/Summary%20of%20Weather.csv', index_col=0)
# Out:
# <ipython-input-26-266f205c3249>:1: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/JimenaAreta/thevalley-MDS/jimena/datasets/Summary%20of%20Weather.csv', index_col=0)

# %%
import statsmodels.formula.api as smf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
import seaborn as sns

# Importo como DF, para que no sólo sea copiar y pegar
df = pd.read_csv('https://raw.githubusercontent.com/JimenaAreta/thevalley-MDS/jimena/datasets/Summary%20of%20Weather.csv', index_col=0)
print(df.shape)
df.head()
# Out:
# (119040, 30)
# <ipython-input-27-09a19fdc0e52>:13: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('https://raw.githubusercontent.com/JimenaAreta/thevalley-MDS/jimena/datasets/Summary%20of%20Weather.csv', index_col=0)
#            Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp Snowfall  \
# STA
# 10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889      0.0
# 10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556      0.0
# 10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444      0.0
# 10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444      0.0
# 10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444      0.0
#
#       PoorWeather  YR  MO  ...  FB FTI  ITH  PGT  TSHDSBRSGF  SD3  RHX RHN  \
# STA                        ...
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
#
#        RVG  WTE
# STA
# 10001  NaN  NaN
# 10001  NaN  NaN
# 10001  NaN  NaN
# 10001  NaN  NaN
# 10001  NaN  NaN
#
# [5 rows x 30 columns]

# %%
X = df['MinTemp']
Y = df['MaxTemp']

print("Type and size of the  vector X:", type(X), X.shape)
print("Type and size of the  vector Y:", type(Y), Y.shape)
# Out:
# Type and size of the  vector X: <class 'pandas.core.series.Series'> (119040,)
# Type and size of the  vector Y: <class 'pandas.core.series.Series'> (119040,)

# %%
#Scatter plot

width = 15
height = 8
plt.figure(figsize=(width, height))

plt.scatter(X,Y)
plt.title('MinTemp vs MaxTemp')
plt.xlabel('MinTemp')
plt.ylabel('MaxTemp')
# Out:
# Text(0, 0.5, 'MaxTemp')

# %%
fit_lm = smf.ols(formula='MaxTemp ~ MinTemp', data=df).fit()
print(fit_lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                MaxTemp   R-squared:                       0.772
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                 4.020e+05
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):               0.00
# Time:                        11:11:34   Log-Likelihood:            -3.3880e+05
# No. Observations:              119040   AIC:                         6.776e+05
# Df Residuals:                  119038   BIC:                         6.776e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     10.7006      0.028    375.909      0.000      10.645      10.756
# MinTemp        0.9188      0.001    634.073      0.000       0.916       0.922
# ==============================================================================
# Omnibus:                    14290.697   Durbin-Watson:                   0.367
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            96900.519
# Skew:                           0.375   Prob(JB):                         0.00
# Kurtosis:                       7.356   Cond. No.                         46.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df.columns
# Out:
# Index(['Date', 'Precip', 'WindGustSpd', 'MaxTemp', 'MinTemp', 'MeanTemp',
#        'Snowfall', 'PoorWeather', 'YR', 'MO', 'DA', 'PRCP', 'DR', 'SPD', 'MAX',
#        'MIN', 'MEA', 'SNF', 'SND', 'FT', 'FB', 'FTI', 'ITH', 'PGT',
#        'TSHDSBRSGF', 'SD3', 'RHX', 'RHN', 'RVG', 'WTE'],
#       dtype='object')

# %% [markdown]
# # Ejercicio
#
# - Prueba diferentes variables para mejorar tu modelo, ¿qué variables pueden influenciar para la máxima temperatura?

# %%
df.head()
# Out:
#            Date Precip  WindGustSpd    MaxTemp    MinTemp   MeanTemp Snowfall  \
# STA
# 10001  1942-7-1  1.016          NaN  25.555556  22.222222  23.888889      0.0
# 10001  1942-7-2      0          NaN  28.888889  21.666667  25.555556      0.0
# 10001  1942-7-3   2.54          NaN  26.111111  22.222222  24.444444      0.0
# 10001  1942-7-4   2.54          NaN  26.666667  22.222222  24.444444      0.0
# 10001  1942-7-5      0          NaN  26.666667  21.666667  24.444444      0.0
#
#       PoorWeather  YR  MO  ...  FB FTI  ITH  PGT  TSHDSBRSGF  SD3  RHX RHN  \
# STA                        ...
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
# 10001         NaN  42   7  ... NaN NaN  NaN  NaN         NaN  NaN  NaN NaN
#
#        RVG  WTE
# STA
# 10001  NaN  NaN
# 10001  NaN  NaN
# 10001  NaN  NaN
# 10001  NaN  NaN
# 10001  NaN  NaN
#
# [5 rows x 30 columns]

# %%
df.describe()
# Out:
#        WindGustSpd        MaxTemp        MinTemp       MeanTemp  \
# count   532.000000  119040.000000  119040.000000  119040.000000
# mean     37.774534      27.045111      17.789511      22.411631
# std      10.297808       8.717817       8.334572       8.297982
# min      18.520000     -33.333333     -38.333333     -35.555556
# 25%      29.632000      25.555556      15.000000      20.555556
# 50%      37.040000      29.444444      21.111111      25.555556
# 75%      43.059000      31.666667      23.333333      27.222222
# max      75.932000      50.000000      34.444444      40.000000
#
#                   YR             MO             DA          DR         SPD  \
# count  119040.000000  119040.000000  119040.000000  533.000000  532.000000
# mean       43.805284       6.726016      15.797530   26.998124   20.396617
# std         1.136718       3.425561       8.794541   15.221732    5.560371
# min        40.000000       1.000000       1.000000    2.000000   10.000000
# 25%        43.000000       4.000000       8.000000   11.000000   16.000000
# 50%        44.000000       7.000000      16.000000   32.000000   20.000000
# 75%        45.000000      10.000000      23.000000   34.000000   23.250000
# max        45.000000      12.000000      31.000000   78.000000   41.000000
#
#                  MAX  ...   FT   FB  FTI  ITH         PGT  SD3  RHX  RHN  RVG  \
# count  118566.000000  ...  0.0  0.0  0.0  0.0  525.000000  0.0  0.0  0.0  0.0
# mean       81.003745  ...  NaN  NaN  NaN  NaN   12.085333  NaN  NaN  NaN  NaN
# std        14.869361  ...  NaN  NaN  NaN  NaN    5.731328  NaN  NaN  NaN  NaN
# min       -28.000000  ...  NaN  NaN  NaN  NaN    0.000000  NaN  NaN  NaN  NaN
# 25%        78.000000  ...  NaN  NaN  NaN  NaN    8.500000  NaN  NaN  NaN  NaN
# 50%        85.000000  ...  NaN  NaN  NaN  NaN   11.600000  NaN  NaN  NaN  NaN
# 75%        89.000000  ...  NaN  NaN  NaN  NaN   15.000000  NaN  NaN  NaN  NaN
# max       122.000000  ...  NaN  NaN  NaN  NaN   23.900000  NaN  NaN  NaN  NaN
#
#        WTE
# count  0.0
# mean   NaN
# std    NaN
# min    NaN
# 25%    NaN
# 50%    NaN
# 75%    NaN
# max    NaN
#
# [8 rows x 23 columns]

# %%
fit_lm = smf.ols(formula='MaxTemp ~ MinTemp + MeanTemp ', data=df).fit()
print(fit_lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                MaxTemp   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.987
# Method:                 Least Squares   F-statistic:                 4.566e+06
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):               0.00
# Time:                        11:11:34   Log-Likelihood:            -1.6758e+05
# No. Observations:              119040   AIC:                         3.352e+05
# Df Residuals:                  119037   BIC:                         3.352e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7596      0.010     77.852      0.000       0.740       0.779
# MinTemp       -0.8798      0.001   -666.920      0.000      -0.882      -0.877
# MeanTemp       1.8712      0.001   1412.204      0.000       1.869       1.874
# ==============================================================================
# Omnibus:                   316238.481   Durbin-Watson:                   1.198
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):      15167401105.062
# Skew:                          31.714   Prob(JB):                         0.00
# Kurtosis:                    1750.547   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# - ¿Tiene sentido el modelo que estamos planteando?

# %%
# Datos de ayer
df['MinTemp_1'] = df['MinTemp'].shift(1)
df['MeanTemp_1'] = df['MeanTemp'].shift(1)

# %%
df['MinTemp'].shift(1)
# Out:
# STA
# 10001          NaN
# 10001    22.222222
# 10001    21.666667
# 10001    22.222222
# 10001    22.222222
#            ...
# 82506    18.888889
# 82506    18.333333
# 82506    18.333333
# 82506    18.333333
# 82506    18.333333
# Name: MinTemp, Length: 119040, dtype: float64

# %%
df['MinTemp']
# Out:
# STA
# 10001    22.222222
# 10001    21.666667
# 10001    22.222222
# 10001    22.222222
# 10001    21.666667
#            ...
# 82506    18.333333
# 82506    18.333333
# 82506    18.333333
# 82506    18.333333
# 82506    17.222222
# Name: MinTemp, Length: 119040, dtype: float64

# %%
fit_lm = smf.ols(formula='MaxTemp ~ MinTemp_1 + MeanTemp_1', data=df).fit()
print(fit_lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                MaxTemp   R-squared:                       0.921
# Model:                            OLS   Adj. R-squared:                  0.921
# Method:                 Least Squares   F-statistic:                 6.923e+05
# Date:                Thu, 08 Feb 2024   Prob (F-statistic):               0.00
# Time:                        11:11:35   Log-Likelihood:            -2.7572e+05
# No. Observations:              119039   AIC:                         5.514e+05
# Df Residuals:                  119036   BIC:                         5.515e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.9876      0.024     82.132      0.000       1.940       2.035
# MinTemp_1     -0.7282      0.003   -222.528      0.000      -0.735      -0.722
# MeanTemp_1     1.6960      0.003    516.045      0.000       1.690       1.702
# ==============================================================================
# Omnibus:                    74407.775   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         52969486.355
# Skew:                           1.642   Prob(JB):                         0.00
# Kurtosis:                     106.289   Cond. No.                         106.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
